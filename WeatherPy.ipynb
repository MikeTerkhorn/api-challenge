# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#set lists for response data

city_id = []
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
wind = []
temp = []

# %%
# Open file to write results of API calls 
myprintlog = open('weatherAPI_printlog.txt', 'w')
myAPIdata = open('weatherAPI_data.csv', 'w')

# header line for csv file
myAPIdata.write("city_id,city_name,country,latitude,longitude,weather_date,temp,humidity,cloudiness,wind_speed\n")

# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

for city in cities:
    query_url = f"{url}q={city}&units=Imperial&appid={weather_api_key}"
    response = requests.get(query_url).json()
    
    try:
        # Create variables for each response item and format to desired datatype
        cityID = int(response['id'])
        cityName = response['name']
        lat_val = response['coord']['lat']
        lon_val = response['coord']['lon']
        weatherDate = (datetime.fromtimestamp(response['dt'])).strftime('%m/%d/%y')
        temperature = response['main']['temp']
        humidity_val = response['main']['humidity']
        cloudiness_val = response['clouds']['all']
        windSpeed = response['wind']['speed']
        
        # Append retreived values to lists above using the variables created above
        city_id.append(cityID)
        city_name.append(cityName)
        lat.append(lat_val)
        lng.append(lon_val)
        date.append(weatherDate)
        temp.append(temperature)
        humidity.append(humidity_val)
        cloudiness.append(cloudiness_val)
        wind.append(windSpeed)
        
        # Output line to terminal to mark progress and store it to a print log text file
        print(f"{cityName} with city ID:{cityID} was found in the Weathermap API\n")
        myprintlog.write(f"{cityName} with city ID:{cityID} was found in the Weathermap API\n")
        
        # Output all retreived values to a csv file
        myAPIdata.write(f"{cityID},{cityName},{lat_val},{lon_val},{weatherDate},\
            {temperature},{humidity_val},{cloudiness_val},{windSpeed}\n")
        
            # Exceptions for a city that is not available in the Weather API
    except:
        
        print(f"{city}, was not found in the Weathermap API\n")
        myprintlog.write(f"{city} was not found in the Weathermap API\n")
        
         # Append null values so lists are all the same length (later we will remove nulls from dataframe)
        city_id.append(None)
        city_name.append(None)
        lat.append(None)
        lng.append(None)
        date.append(None)
        temp.append(None)
        humidity.append(None)
        cloudiness.append(None)
        wind.append(None)
        pass

    
# Close the file handle after completion of the loop
myprintlog.close()
myAPIdata.close()
# Out:
# Bilibino with city ID:2126682 was found in the Weathermap API
#
# nguiu, was not found in the Weathermap API
#
# Puerto Ayora with city ID:3652764 was found in the Weathermap API
#
# El Peñol with city ID:3683508 was found in the Weathermap API
#
# Hermanus with city ID:3366880 was found in the Weathermap API
#
# Saurimo with city ID:145531 was found in the Weathermap API
#
# New Norfolk with city ID:2155415 was found in the Weathermap API
#
# Ilebo with city ID:215976 was found in the Weathermap API
#
# hihifo, was not found in the Weathermap API
#
# Kumul with city ID:1529484 was found in the Weathermap API
#
# Tarko-Sale with city ID:1490085 was found in the Weathermap API
#
# Mar del Plata with city ID:3430863 was found in the Weathermap API
#
# Malmo with city ID:2692969 was found in the Weathermap API
#
# Lebu with city ID:3883457 was found in the Weathermap API
#
# Mandalgovi with city ID:2030065 was found in the Weathermap API
#
# Busselton with city ID:2075265 was found in the Weathermap API
#
# Tura with city ID:1254046 was found in the Weathermap API
#
# Esperance with city ID:2071860 was found in the Weathermap API
#
# Mbarara with city ID:229268 was found in the Weathermap API
#
# Hobart with city ID:2163355 was found in the Weathermap API
#
# Atuona with city ID:4020109 was found in the Weathermap API
#
# Lárdos with city ID:408689 was found in the Weathermap API
#
# Imeni Poliny Osipenko with city ID:2023584 was found in the Weathermap API
#
# Tasiilaq with city ID:3424607 was found in the Weathermap API
#
# Carnarvon with city ID:2074865 was found in the Weathermap API
#
# vaitupu, was not found in the Weathermap API
#
# Mataura with city ID:6201424 was found in the Weathermap API
#
# Nikolskoye with city ID:546105 was found in the Weathermap API
#
# Hilo with city ID:5855927 was found in the Weathermap API
#
# Port Blair with city ID:1259385 was found in the Weathermap API
#
# Marsh Harbour with city ID:3571913 was found in the Weathermap API
#
# Nizhnyaya Tavda with city ID:1497376 was found in the Weathermap API
#
# Jamestown with city ID:5122534 was found in the Weathermap API
#
# Saint-Philippe with city ID:935215 was found in the Weathermap API
#
# Rikitea with city ID:4030556 was found in the Weathermap API
#
# Hong Kong with city ID:1819729 was found in the Weathermap API
#
# Flinders with city ID:6255012 was found in the Weathermap API
#
# Eucaliptus with city ID:3902685 was found in the Weathermap API
#
# Prince Rupert with city ID:6113406 was found in the Weathermap API
#
# grand river south east, was not found in the Weathermap API
#
# Khani with city ID:610864 was found in the Weathermap API
#
# Thompson with city ID:6165406 was found in the Weathermap API
#
# Torbay with city ID:6167817 was found in the Weathermap API
#
# Shimokizukuri with city ID:2129513 was found in the Weathermap API
#
# Barrow with city ID:5880054 was found in the Weathermap API
#
# Skjervøy with city ID:777682 was found in the Weathermap API
#
# Sassandra with city ID:2281951 was found in the Weathermap API
#
# mys shmidta, was not found in the Weathermap API
#
# Nurota with city ID:1513087 was found in the Weathermap API
#
# Cidreira with city ID:3466165 was found in the Weathermap API
#
# Tromsø with city ID:6453316 was found in the Weathermap API
#
# Shimoda with city ID:1852357 was found in the Weathermap API
#
# Kaitangata with city ID:2208248 was found in the Weathermap API
#
# Ushuaia with city ID:3833367 was found in the Weathermap API
#
# São Filipe with city ID:3374210 was found in the Weathermap API
#
# Albany with city ID:5106841 was found in the Weathermap API
#
# Bengkulu with city ID:1649150 was found in the Weathermap API
#
# Bridlington with city ID:2654728 was found in the Weathermap API
#
# Bārmer with city ID:1276901 was found in the Weathermap API
#
# barmer, was not found in the Weathermap API
#
# Romans-sur-Isère with city ID:2983011 was found in the Weathermap API
#
# Tiksi with city ID:2015306 was found in the Weathermap API
#
# Amapá with city ID:3407762 was found in the Weathermap API
#
# Gambēla with city ID:337405 was found in the Weathermap API
#
# gambela, was not found in the Weathermap API
#
# Bambous Virieux with city ID:1106677 was found in the Weathermap API
#
# Daşoguz with city ID:601734 was found in the Weathermap API
#
# dasoguz, was not found in the Weathermap API
#
# Havre-St-Pierre with city ID:5972291 was found in the Weathermap API
#
# Waingapu with city ID:1622318 was found in the Weathermap API
#
# Mount Isa with city ID:2065594 was found in the Weathermap API
#
# belushya guba, was not found in the Weathermap API
#
# rawannawi, was not found in the Weathermap API
#
# Port Alfred with city ID:964432 was found in the Weathermap API
#
# Punta Arenas with city ID:3874787 was found in the Weathermap API
#
# el balyana, was not found in the Weathermap API
#
# Lagoa with city ID:3372964 was found in the Weathermap API
#
# Tuktoyaktuk with city ID:6170031 was found in the Weathermap API
#
# Port Elizabeth with city ID:964420 was found in the Weathermap API
#
# Comodoro Rivadavia with city ID:3860443 was found in the Weathermap API
#
# Dikson with city ID:1507390 was found in the Weathermap API
#
# Thinadhoo with city ID:1337610 was found in the Weathermap API
#
# Isangel with city ID:2136825 was found in the Weathermap API
#
# taolanaro, was not found in the Weathermap API
#
# illoqqortoormiut, was not found in the Weathermap API
#
# tuysarkan, was not found in the Weathermap API
#
# Kapaa with city ID:5848280 was found in the Weathermap API
#
# Atar with city ID:2381334 was found in the Weathermap API
#
# Virginia Beach with city ID:4791259 was found in the Weathermap API
#
# Castro with city ID:3466704 was found in the Weathermap API
#
# Amalāpuram with city ID:1278935 was found in the Weathermap API
#
# amalapuram, was not found in the Weathermap API
#
# Formosa with city ID:3433899 was found in the Weathermap API
#
# Maunabo with city ID:4566208 was found in the Weathermap API
#
# Upernavik with city ID:3418910 was found in the Weathermap API
#
# Saint George with city ID:5546220 was found in the Weathermap API
#
# Nanortalik with city ID:3421765 was found in the Weathermap API
#
# Cape Town with city ID:3369157 was found in the Weathermap API
#
# San Clemente with city ID:5391791 was found in the Weathermap API
#
# Neiafu with city ID:4032420 was found in the Weathermap API
#
# Belaya Gora with city ID:2126785 was found in the Weathermap API
#
# El Carmen with city ID:3684683 was found in the Weathermap API
#
# Borovoy with city ID:1508894 was found in the Weathermap API
#
# Saskylakh with city ID:2017155 was found in the Weathermap API
#
# Ankang with city ID:1789065 was found in the Weathermap API
#
# Cayenne with city ID:3382160 was found in the Weathermap API
#
# Pangnirtung with city ID:6096551 was found in the Weathermap API
#
# Wattegama with city ID:1224061 was found in the Weathermap API
#
# Deoli with city ID:1273083 was found in the Weathermap API
#
# Bahía Blanca with city ID:3865086 was found in the Weathermap API
#
# Avarua with city ID:4035715 was found in the Weathermap API
#
# Røros with city ID:3141332 was found in the Weathermap API
#
# Bodītī with city ID:341877 was found in the Weathermap API
#
# boditi, was not found in the Weathermap API
#
# Quatre Cocos with city ID:1106643 was found in the Weathermap API
#
# Harper with city ID:2276492 was found in the Weathermap API
#
# Dingle with city ID:1714733 was found in the Weathermap API
#
# Padang with city ID:1633419 was found in the Weathermap API
#
# Arlit with city ID:2447513 was found in the Weathermap API
#
# amderma, was not found in the Weathermap API
#
# Takoradze with city ID:2294915 was found in the Weathermap API
#
# Bantou with city ID:1796663 was found in the Weathermap API
#
# Bluff with city ID:2206939 was found in the Weathermap API
#
# Trincomalee with city ID:1226260 was found in the Weathermap API
#
# Vaini with city ID:4032243 was found in the Weathermap API
#
# Antalaha with city ID:1071296 was found in the Weathermap API
#
# Alofi with city ID:4036284 was found in the Weathermap API
#
# Novyy Urgal with city ID:2047258 was found in the Weathermap API
#
# Bowen with city ID:2174444 was found in the Weathermap API
#
# San Pedro del Paraná with city ID:3437022 was found in the Weathermap API
#
# palabuhanratu, was not found in the Weathermap API
#
# Kavieng with city ID:2094342 was found in the Weathermap API
#
# Saldanha with city ID:3361934 was found in the Weathermap API
#
# Kahului with city ID:5847411 was found in the Weathermap API
#
# Lorengau with city ID:2092164 was found in the Weathermap API
# Hithadhoo with city ID:1282256 was found in the Weathermap API
#
# sentyabrskiy, was not found in the Weathermap API
#
# Laguna with city ID:5364271 was found in the Weathermap API
#
# Awjilah with city ID:88533 was found in the Weathermap API
#
# Ponta Delgada with city ID:3372783 was found in the Weathermap API
#
# Cherskiy with city ID:2126199 was found in the Weathermap API
#
# Camaná with city ID:3945985 was found in the Weathermap API
#
# artyk, was not found in the Weathermap API
#
# Neuquén with city ID:3843123 was found in the Weathermap API
#
# Tabou with city ID:2281120 was found in the Weathermap API
#
# Jashpurnagar with city ID:1269177 was found in the Weathermap API
#
# San Cristobal with city ID:3628473 was found in the Weathermap API
#
# George Town with city ID:1735106 was found in the Weathermap API
#
# Bocas del Toro with city ID:3713959 was found in the Weathermap API
#
# Aykhal with city ID:2027296 was found in the Weathermap API
#
# Seoni Mālwa with city ID:1256823 was found in the Weathermap API
#
# seoni malwa, was not found in the Weathermap API
#
# Arraial do Cabo with city ID:3471451 was found in the Weathermap API
#
# Pisco with city ID:3932145 was found in the Weathermap API
#
# barentsburg, was not found in the Weathermap API
#
# Sungai Penuh with city ID:1625929 was found in the Weathermap API
#
# Latur with city ID:1265014 was found in the Weathermap API
#
# Rawson with city ID:3839307 was found in the Weathermap API
#
# Narasannapeta with city ID:1261853 was found in the Weathermap API
#
# Chirongui with city ID:1090415 was found in the Weathermap API
#
# Lavrentiya with city ID:4031637 was found in the Weathermap API
#
# Verāval with city ID:1253237 was found in the Weathermap API
#
# veraval, was not found in the Weathermap API
#
# Eyl with city ID:60019 was found in the Weathermap API
#
# Cadillac with city ID:4987617 was found in the Weathermap API
#
# Doka with city ID:376332 was found in the Weathermap API
#
# Acapulco de Juárez with city ID:3533462 was found in the Weathermap API
#
# Sobolevo with city ID:525426 was found in the Weathermap API
#
# Malinovoye Ozero with city ID:1499779 was found in the Weathermap API
#
# Alice Springs with city ID:2077895 was found in the Weathermap API
#
# Vila do Maio with city ID:3374120 was found in the Weathermap API
#
# Diamantino with city ID:3464724 was found in the Weathermap API
#
# Bredasdorp with city ID:1015776 was found in the Weathermap API
#
# San Joaquin with city ID:3628267 was found in the Weathermap API
#
# Kapoeta with city ID:372884 was found in the Weathermap API
#
# doctor pedro p. pena, was not found in the Weathermap API
#
# Durant with city ID:4535414 was found in the Weathermap API
#
# Waipawa with city ID:2206874 was found in the Weathermap API
#
# Nouadhibou with city ID:2377457 was found in the Weathermap API
#
# Narsaq with city ID:3421719 was found in the Weathermap API
#
# Talnakh with city ID:1490256 was found in the Weathermap API
#
# Ous with city ID:1495812 was found in the Weathermap API
#
# Bloomington with city ID:5018739 was found in the Weathermap API
#
# attawapiskat, was not found in the Weathermap API
#
# Itarema with city ID:3393692 was found in the Weathermap API
#
# Codrington with city ID:2171099 was found in the Weathermap API
#
# Faanui with city ID:4034551 was found in the Weathermap API
#
# Waitati with city ID:2179825 was found in the Weathermap API
#
# Pevek with city ID:2122090 was found in the Weathermap API
#
# Ryōtsu-minato with city ID:1853371 was found in the Weathermap API
#
# ryotsu, was not found in the Weathermap API
#
# Synya with city ID:485215 was found in the Weathermap API
#
# Severo-Kuril'sk with city ID:2121385 was found in the Weathermap API
#
# kuche, was not found in the Weathermap API
#
# Vostok with city ID:2013279 was found in the Weathermap API
#
# Bethel with city ID:5282297 was found in the Weathermap API
#
# Ossora with city ID:2122389 was found in the Weathermap API
#
# Souillac with city ID:933995 was found in the Weathermap API
#
# Viedma with city ID:3832899 was found in the Weathermap API
#
# Pingshan with city ID:1798713 was found in the Weathermap API
#
# Kudahuvadhoo with city ID:1337607 was found in the Weathermap API
#
# Baker City with city ID:5712169 was found in the Weathermap API
#
# tidore, was not found in the Weathermap API
#
# marcona, was not found in the Weathermap API
#
# Ürümqi with city ID:1529102 was found in the Weathermap API
#
# Hofn with city ID:2630299 was found in the Weathermap API
#
# Ballina with city ID:2177069 was found in the Weathermap API
#
# Ilulissat with city ID:3423146 was found in the Weathermap API
#
# Yulara with city ID:6355222 was found in the Weathermap API
#
# Sydney Mines with city ID:7303783 was found in the Weathermap API
#
# Geraldton with city ID:2070998 was found in the Weathermap API
#
# Motzorongo with city ID:3522923 was found in the Weathermap API
#
# Imbituba with city ID:3461370 was found in the Weathermap API
#
# Shangqiu with city ID:1783934 was found in the Weathermap API
#
# Adrar with city ID:2381972 was found in the Weathermap API
#
# Lompoc with city ID:5367788 was found in the Weathermap API
#
# Dezhou with city ID:1812955 was found in the Weathermap API
#
# Qaanaaq with city ID:3831208 was found in the Weathermap API
#
# Kruisfontein with city ID:986717 was found in the Weathermap API
#
# Asău with city ID:686090 was found in the Weathermap API
#
# asau, was not found in the Weathermap API
#
# Anloga with city ID:2304548 was found in the Weathermap API
#
# Touros with city ID:3386213 was found in the Weathermap API
#
# bargal, was not found in the Weathermap API
#
# Hamelin with city ID:2911271 was found in the Weathermap API
#
# Bellavista with city ID:3699364 was found in the Weathermap API
#
# bolungarvik, was not found in the Weathermap API
#
# dolbeau, was not found in the Weathermap API
#
# Kenai with city ID:5866063 was found in the Weathermap API
#
# Cockburn Town with city ID:3576994 was found in the Weathermap API
#
# Grindavik with city ID:3416888 was found in the Weathermap API
#
# ardistan, was not found in the Weathermap API
#
# Haifa with city ID:294801 was found in the Weathermap API
#
# Vao with city ID:2137773 was found in the Weathermap API
#
# Ribeira Grande with city ID:3372707 was found in the Weathermap API
#
# Yangi Marg`ilon with city ID:1513491 was found in the Weathermap API
#
# Eretria with city ID:262628 was found in the Weathermap API
#
# Tessalit with city ID:2449893 was found in the Weathermap API
#
# halalo, was not found in the Weathermap API
#
# Oranjemund with city ID:3354071 was found in the Weathermap API
#
# Los Llanos de Aridane with city ID:2514651 was found in the Weathermap API
#
# Nishihara with city ID:1855342 was found in the Weathermap API
#
# Skowhegan with city ID:4978701 was found in the Weathermap API
#
# Masterton with city ID:2206890 was found in the Weathermap API
#
# Rusape with city ID:882100 was found in the Weathermap API
#
# nizhneyansk, was not found in the Weathermap API
#
# Batagay with city ID:2027044 was found in the Weathermap API
#
# Vila with city ID:7117100 was found in the Weathermap API
#
# East London with city ID:1006984 was found in the Weathermap API
#
# Elizabeth City with city ID:4465088 was found in the Weathermap API
#
# Khovd with city ID:1516048 was found in the Weathermap API
#
# Longyearbyen with city ID:2729907 was found in the Weathermap API
#
# Iqaluit with city ID:5983720 was found in the Weathermap API
#
# Nyaunglebin with city ID:1303406 was found in the Weathermap API
#
# Encruzilhada do Sul with city ID:3464255 was found in the Weathermap API
#
# Kisaran with city ID:1214882 was found in the Weathermap API
#
# Taunggyi with city ID:1293960 was found in the Weathermap API
#
# Najrān with city ID:103630 was found in the Weathermap API
#
# najran, was not found in the Weathermap API
#
# Saint Paul Harbor with city ID:5866583 was found in the Weathermap API
#
# Fare with city ID:4034496 was found in the Weathermap API
#
# Benin with city ID:2395170 was found in the Weathermap API
#
# saleaula, was not found in the Weathermap API
#
# Gizo Government Station with city ID:2108857 was found in the Weathermap API
#
# Hobyo with city ID:57000 was found in the Weathermap API
#
# sumbawa, was not found in the Weathermap API
#
# Yellowknife with city ID:6185377 was found in the Weathermap API
#
# Moose Factory with city ID:6078372 was found in the Weathermap API
#
# Coromandel with city ID:3465487 was found in the Weathermap API
#
# Khandyga with city ID:2022773 was found in the Weathermap API
# Torit with city ID:365742 was found in the Weathermap API
#
# Ambilobe with city ID:1082243 was found in the Weathermap API
#
# Sinnamary with city ID:3380290 was found in the Weathermap API
#
# Puerto Carreño with city ID:3671519 was found in the Weathermap API
#
# Oktyabr'skoye with city ID:515805 was found in the Weathermap API
#
# lolua, was not found in the Weathermap API
#
# Palembang with city ID:1633070 was found in the Weathermap API
#
# Guerrero Negro with city ID:4021858 was found in the Weathermap API
#
# aybak, was not found in the Weathermap API
#
# Ponta do Sol with city ID:2264557 was found in the Weathermap API
#
# Yazman with city ID:1162316 was found in the Weathermap API
#
# Nísia Floresta with city ID:3393922 was found in the Weathermap API
#
# Evensk with city ID:2125693 was found in the Weathermap API
#
# Fes with city ID:2548885 was found in the Weathermap API
#
# Jalu with city ID:86049 was found in the Weathermap API
#
# Zheleznodorozhnyy with city ID:463355 was found in the Weathermap API
#
# Mitsamiouli with city ID:921786 was found in the Weathermap API
#
# Umm Hājar with city ID:2426370 was found in the Weathermap API
#
# oum hadjer, was not found in the Weathermap API
#
# Laas with city ID:3175096 was found in the Weathermap API
#
# Rondonópolis with city ID:3450909 was found in the Weathermap API
#
# Anjozorobe with city ID:1073482 was found in the Weathermap API
#
# Doha with city ID:290030 was found in the Weathermap API
#
# tsihombe, was not found in the Weathermap API
#
# Kawalu with city ID:1640902 was found in the Weathermap API
#
# jakoruda, was not found in the Weathermap API
#
# Caesarea with city ID:7117228 was found in the Weathermap API
#
# Loncoche with city ID:3882582 was found in the Weathermap API
#
# Vizinga with city ID:473263 was found in the Weathermap API
#
# Shiraoi with city ID:2128072 was found in the Weathermap API
#
# Road Town with city ID:3577430 was found in the Weathermap API
#
# Sørland with city ID:3137469 was found in the Weathermap API
#
# Kloulklubed with city ID:7671223 was found in the Weathermap API
#
# Northport with city ID:4080555 was found in the Weathermap API
#
# Kilvelur with city ID:1266540 was found in the Weathermap API
#
# Deputatsky with city ID:2028164 was found in the Weathermap API
#
# Bad Freienwalde with city ID:2953458 was found in the Weathermap API
#
# Lucapa with city ID:145724 was found in the Weathermap API
#
# Kimbe with city ID:2093967 was found in the Weathermap API
#
# Leningradskiy with city ID:2123814 was found in the Weathermap API
#
# Jaraguá with city ID:3460107 was found in the Weathermap API
#
# Luoyang with city ID:1801792 was found in the Weathermap API
#
# Linjiang with city ID:2036069 was found in the Weathermap API
#
# Atambua with city ID:1651103 was found in the Weathermap API
#
# Airai with city ID:1651810 was found in the Weathermap API
#
# tasbuget, was not found in the Weathermap API
#
# Cabo San Lucas with city ID:3985710 was found in the Weathermap API
#
# Butaritari with city ID:2110227 was found in the Weathermap API
#
# Bariadi with city ID:161218 was found in the Weathermap API
#
# Saint-François with city ID:2980080 was found in the Weathermap API
#
# Kavaratti with city ID:1267390 was found in the Weathermap API
#
# Montluçon with city ID:2992292 was found in the Weathermap API
#
# Cervo with city ID:3125287 was found in the Weathermap API
#
# Price with city ID:5545269 was found in the Weathermap API
#
# Poum with city ID:2138555 was found in the Weathermap API
#
# Sabang with city ID:1214026 was found in the Weathermap API
#
# Philadelphia with city ID:4560349 was found in the Weathermap API
#
# Mandurah with city ID:2067119 was found in the Weathermap API
#
# Charagua with city ID:3921141 was found in the Weathermap API
#
# Provideniya with city ID:4031574 was found in the Weathermap API
#
# Kapit with city ID:1737185 was found in the Weathermap API
#
# Saltillo with city ID:3988086 was found in the Weathermap API
#
# Brigantine with city ID:4500920 was found in the Weathermap API
#
# Aden with city ID:415189 was found in the Weathermap API
#
# Faya with city ID:110690 was found in the Weathermap API
#
# Anadyr with city ID:2127202 was found in the Weathermap API
#
# Polunochnoye with city ID:1494482 was found in the Weathermap API
#
# Manjacaze with city ID:1040938 was found in the Weathermap API
#
# Salisbury with city ID:2638664 was found in the Weathermap API
#
# Labuhan with city ID:8079926 was found in the Weathermap API
#
# Bairnsdale with city ID:2177233 was found in the Weathermap API
#
# skalistyy, was not found in the Weathermap API
#
# Kita with city ID:2455216 was found in the Weathermap API
#
# São João da Barra with city ID:3448903 was found in the Weathermap API
#
# Beringovskiy with city ID:2126710 was found in the Weathermap API
#
# Vila Velha with city ID:3445026 was found in the Weathermap API
#
# Klaksvík with city ID:2618795 was found in the Weathermap API
#
# Gornyak with city ID:1506260 was found in the Weathermap API
#
# Ostrovnoy with city ID:556268 was found in the Weathermap API
#
# Klyuchevskiy with city ID:2021980 was found in the Weathermap API
#
# Torbat-e Jām with city ID:1159362 was found in the Weathermap API
#
# torbat-e jam, was not found in the Weathermap API
#
# Taoudenni with city ID:2450173 was found in the Weathermap API
#
# Ahipara with city ID:2194098 was found in the Weathermap API
#
# Bac Lieu with city ID:1591474 was found in the Weathermap API
#
# Westport with city ID:4845585 was found in the Weathermap API
#
# Timrå with city ID:2669047 was found in the Weathermap API
#
# Zhezkazgan with city ID:1516589 was found in the Weathermap API
#
# Luwuk with city ID:1637001 was found in the Weathermap API
#
# Marzuq with city ID:72181 was found in the Weathermap API
#
# ‘Ewa Beach with city ID:5855051 was found in the Weathermap API
#
# Uni with city ID:478996 was found in the Weathermap API
#
# Coahuayana Viejo with city ID:4013679 was found in the Weathermap API
#
# warqla, was not found in the Weathermap API
#
# Vostochnyy with city ID:471501 was found in the Weathermap API
#
# Gloggnitz with city ID:2778455 was found in the Weathermap API
#
# Tuatapere with city ID:2180815 was found in the Weathermap API
#
# Zhaotong with city ID:1784841 was found in the Weathermap API
#
# Broken Hill with city ID:2173911 was found in the Weathermap API
#
# chagda, was not found in the Weathermap API
#
# Santa Cruz de la Sierra with city ID:3904906 was found in the Weathermap API
#
# Opuwo with city ID:3354077 was found in the Weathermap API
#
# Tikhvin with city ID:483019 was found in the Weathermap API
#
# Bell Ville with city ID:3864331 was found in the Weathermap API
#
# Putina with city ID:3931137 was found in the Weathermap API
#
# Leninsk with city ID:536156 was found in the Weathermap API
#
# Angoche with city ID:1052944 was found in the Weathermap API
#
# Nicoya with city ID:3622716 was found in the Weathermap API
#
# Fortuna with city ID:5563839 was found in the Weathermap API
#
# Kaeo with city ID:2189343 was found in the Weathermap API
#
# Owando with city ID:2255542 was found in the Weathermap API
#
# Rome with city ID:5134295 was found in the Weathermap API
#
# karamay, was not found in the Weathermap API
#
# Ust'-Ishim with city ID:1488206 was found in the Weathermap API
#
# Port Hedland with city ID:2063042 was found in the Weathermap API
#
# Baculin with city ID:1729469 was found in the Weathermap API
#
# Burhaniye with city ID:320369 was found in the Weathermap API
#
# Inhambane with city ID:1045114 was found in the Weathermap API
#
# Guarapari with city ID:3461888 was found in the Weathermap API
#
# Gweta with city ID:933734 was found in the Weathermap API
#
# Matara with city ID:1235846 was found in the Weathermap API
#
# Grand-Santi with city ID:3381538 was found in the Weathermap API
#
# tarudant, was not found in the Weathermap API
#
# kamenskoye, was not found in the Weathermap API
#
# Lázaro Cárdenas with city ID:4026082 was found in the Weathermap API
#
# Sabha with city ID:2212775 was found in the Weathermap API
#
# St. George's with city ID:3579925 was found in the Weathermap API
#
# Shingū with city ID:1847947 was found in the Weathermap API
#
# shingu, was not found in the Weathermap API
#
# Le Mée-sur-Seine with city ID:3003481 was found in the Weathermap API
#
# San Quintín with city ID:3984997 was found in the Weathermap API
#
# Tucupita with city ID:3625929 was found in the Weathermap API
#
# Tigre with city ID:3427761 was found in the Weathermap API
#
# Gamba with city ID:2400547 was found in the Weathermap API
# Saint-Pierre with city ID:935214 was found in the Weathermap API
#
# Şebinkarahisar with city ID:739914 was found in the Weathermap API
#
# sebinkarahisar, was not found in the Weathermap API
#
# Mumford with city ID:2297810 was found in the Weathermap API
#
# Mulegé with city ID:3995236 was found in the Weathermap API
#
# Khatanga with city ID:2022572 was found in the Weathermap API
#
# Gravdal with city ID:3155152 was found in the Weathermap API
#
# Tocopilla with city ID:3869716 was found in the Weathermap API
#
# Mehamn with city ID:778707 was found in the Weathermap API
#
# Khorinsk with city ID:2022304 was found in the Weathermap API
#
# Harpanahalli with city ID:1270287 was found in the Weathermap API
#
# Nampula with city ID:1033356 was found in the Weathermap API
#
# Hasaki with city ID:2112802 was found in the Weathermap API
#
# Baruun-Urt with city ID:2032614 was found in the Weathermap API
#
# Teya with city ID:1489656 was found in the Weathermap API
#
# Borås with city ID:2720501 was found in the Weathermap API
#
# Camocim with city ID:3403687 was found in the Weathermap API
#
# Srandakan with city ID:1626493 was found in the Weathermap API
#
# Kigonsera with city ID:878400 was found in the Weathermap API
#
# Fort Nelson with city ID:5955902 was found in the Weathermap API
#
# Griffith with city ID:4920986 was found in the Weathermap API
#
# Batouri with city ID:2234663 was found in the Weathermap API
#
# Broome with city ID:5110365 was found in the Weathermap API
#
# Nantucket with city ID:4944903 was found in the Weathermap API
#
# Las Tunas with city ID:3550598 was found in the Weathermap API
#
# Muros with city ID:3115824 was found in the Weathermap API
#
# Chara with city ID:2025630 was found in the Weathermap API
#
# Xining with city ID:1788852 was found in the Weathermap API
#
# Plettenberg Bay with city ID:964712 was found in the Weathermap API
#
# Øksfjord with city ID:778362 was found in the Weathermap API
#
# Itamaracá with city ID:3397963 was found in the Weathermap API
#
# Samsun Province with city ID:740263 was found in the Weathermap API
#
# Bay Roberts with city ID:5895424 was found in the Weathermap API
#
# Kuala Terengganu with city ID:1734705 was found in the Weathermap API
#
# Makakilo City with city ID:5850554 was found in the Weathermap API
#
# Clyde River with city ID:5924351 was found in the Weathermap API
#
# Krasnosel'kup with city ID:1502073 was found in the Weathermap API
#
# Phuket with city ID:1151253 was found in the Weathermap API
#
# Sheridan with city ID:5838199 was found in the Weathermap API
#
# Mocuba with city ID:1024312 was found in the Weathermap API
#
# Chapais with city ID:5919850 was found in the Weathermap API
#
# Belyy Yar with city ID:1510377 was found in the Weathermap API
#
# Alyangula with city ID:2079582 was found in the Weathermap API
#
# Egvekinot with city ID:4031742 was found in the Weathermap API
#
# Muisne with city ID:3653967 was found in the Weathermap API
#
# Stornoway with city ID:2636790 was found in the Weathermap API
#
# Juegang with city ID:1804979 was found in the Weathermap API
#
# Kerman with city ID:128234 was found in the Weathermap API
#
# Suntar with city ID:2015913 was found in the Weathermap API
#
# Tiznit Province with city ID:2527087 was found in the Weathermap API
#
# Muli with city ID:1337617 was found in the Weathermap API
#
# Den Helder with city ID:2757220 was found in the Weathermap API
#
# Soyo with city ID:2236967 was found in the Weathermap API
#
# Sayyan with city ID:70979 was found in the Weathermap API
#
# Santa Maria with city ID:3450083 was found in the Weathermap API
#
# Sulphur Springs with city ID:4734909 was found in the Weathermap API
#
# Terney with city ID:2015352 was found in the Weathermap API
#
# Finspång with city ID:2714903 was found in the Weathermap API
#
# Okakarara with city ID:3354876 was found in the Weathermap API
#
# San Rafael with city ID:3836669 was found in the Weathermap API
#
# Lüderitz with city ID:3355672 was found in the Weathermap API
#
# Hongjiang with city ID:1808106 was found in the Weathermap API
#
# kerki, was not found in the Weathermap API
#
# Maceió with city ID:3395981 was found in the Weathermap API
#
# Ribeira Brava with city ID:2263905 was found in the Weathermap API
#
# Sotik Post with city ID:200308 was found in the Weathermap API
#
# Sosnovo with city ID:490213 was found in the Weathermap API
#
# Erzin with city ID:296852 was found in the Weathermap API
#
# Rocha with city ID:3440777 was found in the Weathermap API
#
# Cascais with city ID:2269594 was found in the Weathermap API
#
# Dhemāji with city ID:1272783 was found in the Weathermap API
#
# dhemaji, was not found in the Weathermap API
#
# Juradó with city ID:3680090 was found in the Weathermap API
#
# Muravlenko with city ID:1540711 was found in the Weathermap API
#
# Novospasskoye with city ID:517897 was found in the Weathermap API
#
# Melito di Porto Salvo with city ID:2524181 was found in the Weathermap API
#
# Vardø with city ID:777019 was found in the Weathermap API
#
# Kurchum with city ID:1521762 was found in the Weathermap API
#
# Bagru with city ID:1273690 was found in the Weathermap API
#
# Chui with city ID:3443061 was found in the Weathermap API
#
# Necochea with city ID:3430443 was found in the Weathermap API
#
# Ormara with city ID:1168700 was found in the Weathermap API
#
# Ngunguru with city ID:2186111 was found in the Weathermap API
#
# Talcahuano with city ID:3870282 was found in the Weathermap API
#
# Ust-Nera with city ID:2120048 was found in the Weathermap API
#
# Soe with city ID:1626703 was found in the Weathermap API
#
# Velikiy Ustyug with city ID:476062 was found in the Weathermap API
#
# Grootfontein with city ID:3357114 was found in the Weathermap API
#
# Praia with city ID:3374333 was found in the Weathermap API
#
# Dallas with city ID:4684904 was found in the Weathermap API
#
# samusu, was not found in the Weathermap API
#
# karauzyak, was not found in the Weathermap API
#
# skjaerhollen, was not found in the Weathermap API
#
# Ancud with city ID:3899695 was found in the Weathermap API
#
# Dakar with city ID:2253354 was found in the Weathermap API
#
# Filingué with city ID:2444995 was found in the Weathermap API
#
# Taree with city ID:2147381 was found in the Weathermap API
#
# Lucea with city ID:3489657 was found in the Weathermap API
#
# Santa Fe with city ID:3836277 was found in the Weathermap API
#
# Esim with city ID:2303611 was found in the Weathermap API
#
# Usta Muhammad with city ID:1162868 was found in the Weathermap API
#
# Vicuña with city ID:3868308 was found in the Weathermap API
#
# Luganville with city ID:2136150 was found in the Weathermap API
#
# Kirn with city ID:2890314 was found in the Weathermap API
#
# Bathsheba with city ID:3374083 was found in the Weathermap API
#
# Sitka with city ID:5557293 was found in the Weathermap API
#
# Panalingaan with city ID:1695736 was found in the Weathermap API
#
# Hwange with city ID:889942 was found in the Weathermap API
#
# Russell with city ID:4047434 was found in the Weathermap API
#
# Paulo Ramos with city ID:3392731 was found in the Weathermap API
#
# Rio Grande with city ID:3451138 was found in the Weathermap API
#
# San Patricio with city ID:3985168 was found in the Weathermap API
#
# Pemba with city ID:1028918 was found in the Weathermap API
#
# Campos do Jordão with city ID:3467684 was found in the Weathermap API
#
# Srednekolymsk with city ID:2121025 was found in the Weathermap API
#
# Carauari with city ID:3664659 was found in the Weathermap API
#
# Chokurdakh with city ID:2126123 was found in the Weathermap API
#
# Muroto-misakicho with city ID:1856392 was found in the Weathermap API
#
# Diré with city ID:2458624 was found in the Weathermap API
#
# bur gabo, was not found in the Weathermap API
#
# Kangaatsiaq with city ID:3422683 was found in the Weathermap API
#
# Cap Malheureux with city ID:934649 was found in the Weathermap API
#
# Zwedru with city ID:2272491 was found in the Weathermap API
#
# Morón with city ID:3430545 was found in the Weathermap API
#
# Hobe Sound with city ID:4158758 was found in the Weathermap API
#
# Merauke with city ID:2082539 was found in the Weathermap API
#
# Buala with city ID:2109528 was found in the Weathermap API
#
# Chernyshevskiy with city ID:2025456 was found in the Weathermap API
#
# Roebourne with city ID:2062276 was found in the Weathermap API
#
# Fort Collins with city ID:5577147 was found in the Weathermap API
#
# Mahanje with city ID:155285 was found in the Weathermap API
#
# Te Anau with city ID:2181625 was found in the Weathermap API
#
# Riohacha with city ID:3670745 was found in the Weathermap API
# louisbourg, was not found in the Weathermap API
#
# Pristen' with city ID:505154 was found in the Weathermap API
#
# Mersing with city ID:1732826 was found in the Weathermap API
#
# Kirkconnel with city ID:2645291 was found in the Weathermap API
#
# Novobureyskiy with city ID:2018964 was found in the Weathermap API
#
# Okhotsk with city ID:2122605 was found in the Weathermap API
#
# Ulkan with city ID:2020208 was found in the Weathermap API
#
# Alanya with city ID:324190 was found in the Weathermap API
#
# Amazar with city ID:2027806 was found in the Weathermap API
#
# Wanning with city ID:1791779 was found in the Weathermap API
#
# tsienyane, was not found in the Weathermap API
#
# Otradnoye with city ID:513898 was found in the Weathermap API
#
# Olinda with city ID:3393536 was found in the Weathermap API
#
# Balabac with city ID:1728675 was found in the Weathermap API
#
# Hamilton with city ID:4513583 was found in the Weathermap API
#
# Knysna with city ID:988698 was found in the Weathermap API
#
# Isil'kul' with city ID:1505438 was found in the Weathermap API
#
# Mahajanga with city ID:1062663 was found in the Weathermap API
#
# mocambique, was not found in the Weathermap API
#
# Wajir with city ID:178443 was found in the Weathermap API
#
# Vrede with city ID:942701 was found in the Weathermap API
#
# Conde with city ID:3385077 was found in the Weathermap API
#
# Eunice with city ID:4323900 was found in the Weathermap API
#
# Puerto Madryn with city ID:3840092 was found in the Weathermap API
#
# Matagami with city ID:6067747 was found in the Weathermap API
#
# Nokaneng with city ID:933211 was found in the Weathermap API
#
# La Ronge with city ID:6050066 was found in the Weathermap API
#
# Saint Anthony with city ID:5044290 was found in the Weathermap API
#
# Dahuk with city ID:96994 was found in the Weathermap API
#
# Serebryansk with city ID:1519395 was found in the Weathermap API
#
# Spassk-Ryazanskiy with city ID:489741 was found in the Weathermap API
#
# Pontes e Lacerda with city ID:3453060 was found in the Weathermap API
#
# Nichinan with city ID:1855476 was found in the Weathermap API
#
# Balakhninskiy with city ID:2027196 was found in the Weathermap API
#
# Raudeberg with city ID:3146487 was found in the Weathermap API
#
# Sorong with city ID:1626542 was found in the Weathermap API
#
# Umluj with city ID:100926 was found in the Weathermap API
#
# Dinga with city ID:1179790 was found in the Weathermap API
#
# Nanhyanga with city ID:877588 was found in the Weathermap API
#
# Río Gallegos with city ID:3838859 was found in the Weathermap API
#
# Mount Gambier with city ID:2156643 was found in the Weathermap API
#
# Mezhdurechensk with city ID:1498920 was found in the Weathermap API
#
# Kokopo with city ID:2093685 was found in the Weathermap API
#
# Dickinson with city ID:4686163 was found in the Weathermap API
#
# Ilhabela with city ID:3461425 was found in the Weathermap API
#
# Miyako with city ID:2111884 was found in the Weathermap API
#
# Pineville with city ID:4337291 was found in the Weathermap API
#
# Kumluca with city ID:305681 was found in the Weathermap API
#
# Mareeba with city ID:2158767 was found in the Weathermap API
#
# Weligama with city ID:1223738 was found in the Weathermap API
#
# Bonthe with city ID:2409914 was found in the Weathermap API
#
# Bonavista with city ID:5905393 was found in the Weathermap API
#
# Praia da Vitória with city ID:3372760 was found in the Weathermap API
#
# Liku with city ID:1633034 was found in the Weathermap API
#
# Yeppoon with city ID:2142316 was found in the Weathermap API
#
# Batemans Bay with city ID:2176639 was found in the Weathermap API
#
# Dwārka with city ID:1272140 was found in the Weathermap API
#
# dwarka, was not found in the Weathermap API
#
# Lakatoro with city ID:2136697 was found in the Weathermap API
#
# Benguela with city ID:3351663 was found in the Weathermap API
#
# Mbinga with city ID:877998 was found in the Weathermap API
#
# Cotonou with city ID:2394819 was found in the Weathermap API
#
# Farsund with city ID:3157799 was found in the Weathermap API
#
# Mahébourg with city ID:934322 was found in the Weathermap API
#
# Muncie with city ID:4924006 was found in the Weathermap API
#
# Nagapattinam with city ID:1262260 was found in the Weathermap API
#
# Sambava with city ID:1056899 was found in the Weathermap API
#
# Brae with city ID:2654970 was found in the Weathermap API
#
# Rundu with city ID:3353383 was found in the Weathermap API
#
# mentok, was not found in the Weathermap API
#
# Bandrele with city ID:1090397 was found in the Weathermap API
#
# Juneau with city ID:5554072 was found in the Weathermap API
#
# Aldan with city ID:2027968 was found in the Weathermap API
#
# Isiolo with city ID:196231 was found in the Weathermap API
#
# Terra Santa with city ID:3386467 was found in the Weathermap API
#
# Half Moon Bay with city ID:5354943 was found in the Weathermap API
#
# Rio Negrinho with city ID:3451124 was found in the Weathermap API
#
# Baykit with city ID:1510689 was found in the Weathermap API
#
# Ulladulla with city ID:2145554 was found in the Weathermap API
#
# Goderich with city ID:5962442 was found in the Weathermap API
#
# Acajutla with city ID:3587498 was found in the Weathermap API
#
# Henties Bay with city ID:3356832 was found in the Weathermap API
#
# Vigeland with city ID:3131848 was found in the Weathermap API
#
# solovetskiy, was not found in the Weathermap API
#
# Madang with city ID:2091996 was found in the Weathermap API
#
# Jászszentandrás with city ID:719635 was found in the Weathermap API
#
# Vestmannaeyjar with city ID:3412093 was found in the Weathermap API
#
# Villa Bruzual with city ID:3625346 was found in the Weathermap API
#
# Bintulu with city ID:1737486 was found in the Weathermap API
#
# Dunedin with city ID:2191562 was found in the Weathermap API
#
# Eureka with city ID:5563397 was found in the Weathermap API
#
# Sampit with city ID:1628884 was found in the Weathermap API
#
# Khor with city ID:2022317 was found in the Weathermap API
#
# Joanópolis with city ID:3459855 was found in the Weathermap API
#
# Sibolga with city ID:1213855 was found in the Weathermap API
#
# Plymouth with city ID:4947607 was found in the Weathermap API
#
# Fushun with city ID:2037355 was found in the Weathermap API
#
# Ferry Pass with city ID:4155017 was found in the Weathermap API
#
# Leticia with city ID:3676623 was found in the Weathermap API
#
# Barra Patuca with city ID:3614835 was found in the Weathermap API
#
# sahrak, was not found in the Weathermap API
#
# Kajiado with city ID:195298 was found in the Weathermap API
#
# Qaqortoq with city ID:3420846 was found in the Weathermap API

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a dictionary from the lists that we created above
weather_dict = {
    "city_id": city_id,
    "city_name": city_name,
    "latitude": lat,
    "longitude": lng,
    "date": date,
    "temp": temp,
    "humidity": humidity,
    "cloudiness": cloudiness,
    "wind": wind
}

# Use the dictionary to create a dataframe named weather_data
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#      city_id     city_name  latitude  longitude      date   temp  humidity  \
# 0  2126682.0      Bilibino     68.05     166.44  08/11/20  38.32      82.0
# 1        NaN          None       NaN        NaN      None    NaN       NaN
# 2  3652764.0  Puerto Ayora     -0.74     -90.35  08/11/20  70.02      73.0
# 3  3683508.0      El Peñol      1.46     -77.45  08/11/20  75.20      50.0
# 4  3366880.0      Hermanus    -34.42      19.23  08/11/20  54.00      84.0
#
#    cloudiness  wind
# 0        85.0  1.05
# 1         NaN   NaN
# 2        75.0  8.05
# 3        40.0  6.93
# 4        48.0  8.99

# %%
# Make a dataframe that has only non-null values (so linear regression can be done later)
# First drop the NaN values
weather_data_values = weather_data.dropna()

# Reset the index (it will have gaps in it where the NaN value rows have been deleted)
weather_data_values = weather_data_values.reset_index(drop=True)

# Change the datatype for the city_id field to an integer (it gets created as a float)
weather_data_values['city_id'] = weather_data_values['city_id'].astype(int)
weather_data_values.head()
# Out:
#    city_id     city_name  latitude  longitude      date   temp  humidity  \
# 0  2126682      Bilibino     68.05     166.44  08/11/20  38.32      82.0
# 1  3652764  Puerto Ayora     -0.74     -90.35  08/11/20  70.02      73.0
# 2  3683508      El Peñol      1.46     -77.45  08/11/20  75.20      50.0
# 3  3366880      Hermanus    -34.42      19.23  08/11/20  54.00      84.0
# 4   145531       Saurimo     -9.66      20.39  08/11/20  78.01      18.0
#
#    cloudiness  wind
# 0        85.0  1.05
# 1        75.0  8.05
# 2        40.0  6.93
# 3        48.0  8.99
# 4         0.0  3.31

# %%
weather_data_values.to_csv("cities.csv", index = False, encoding="utf-8")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for Latitude vs.Temperature in Fahrenheit
weatherDate = weather_data_values['date'][0]
plt.scatter(weather_data_values["latitude"], weather_data_values["temp"], marker="o",edgecolors='black')

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Temperature {weatherDate}")
plt.ylabel("Temperature (Fahrenheit)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Images/LatitudeVsTemperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for Latitude vs. Humidity
plt.scatter(weather_data_values["latitude"], weather_data_values["humidity"], marker="o",edgecolors='black')

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity {weatherDate}")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Images/LatitudeVsHumidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for Latitude vs. Cloudiness
plt.scatter(weather_data_values["latitude"], weather_data_values["cloudiness"], marker="o",edgecolors='black')

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness {weatherDate}")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Images/LatitudeVsCloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for Latitude vs. Wind Speed
plt.scatter(weather_data_values["latitude"], weather_data_values["wind"], marker="o",edgecolors='black')

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed {weatherDate}")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Images/LatitudeVsWindSpeed.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
